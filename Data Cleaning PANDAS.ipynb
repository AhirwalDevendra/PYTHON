# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\DEVEN\Desktop\FINALE\python\Cleaning\Customer Call List.xlsx")

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.shape
# Out:
# (21, 8)

# %%
print(df.duplicated().sum()) #count duplicate in dataframe
# Out:
# 1

# %%
df.duplicated(subset='First_Name', keep='last').sum()
# Out:
# 2

# %%
df.duplicated(keep='first')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
# delete 19 keep 20

# %%
df.drop_duplicates()
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.drop_duplicates(keep='last')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df1=df.drop(columns=['Not_Useful_Column','Address'])

# %%
df1.shape
# Out:
# (21, 6)

# %%
df1=df1.drop_duplicates()

# %%
df1.shape
# Out:
# (20, 6)

# %%
df=df.drop(columns='Not_Useful_Column') # specific columns

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'].str.lstrip()
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.lstrip('/')  # removed / from whole column ,,from left
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.lstrip('...')# removed ...
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.rstrip('_') # removed _ from right
# Out:
# 0        Baggins
# 1          Nadir
# 2         /White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11     ...Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name']   #did not saved any changes
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.strip('...,/,_') #removed every unnecessary at once
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name']=df['Last_Name'].str.strip('...,/,_')  # we reassigned it,we could have use inplace

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df1['Last_Name'].str.replace('/',"")
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df1['Last_Name'].str.replace('/',"")  # replace is complicated while multiple replacement ,,strip is more easy
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123/643/9775              No
# 2         1003     Walter       /White    7066950392               N
# 3         1004     Dwight      Schrute  123-543-2345             Yes
# 4         1005        Jon         Snow  876|678|3469               Y
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger           NaN              No
# 7         1008   Sherlock       Holmes  876|678|3469               N
# 8         1009    Gandalf          NaN           N/a             Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee           NaN             Yes
# 11        1012      Harry    ...Potter    7066950392               Y
# 12        1013        Don       Draper  123-543-2345             Yes
# ...

# %%
df1['Phone_Number'].str.replace('[^a-zA-Z0-9]',"")
# Out:
# C:\Users\DEVEN\AppData\Local\Temp\ipykernel_24052\3087228691.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Phone_Number'].str.replace('[^a-zA-Z0-9]',"")
# 0     1235455421
# 1     1236439775
# 2            NaN
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            NaN
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           NaN
# 11           NaN
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17           NaN
# 18            Na
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df1['Phone_Number']=df1['Phone_Number'].str.replace('[^a-zA-Z0-9]',"")  # replace need reassigned not inplace
# Out:
# C:\Users\DEVEN\AppData\Local\Temp\ipykernel_24052\1201438691.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['Phone_Number']=df1['Phone_Number'].str.replace('[^a-zA-Z0-9]',"")  # replace need reassigned not inplace

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421             Yes
# 1         1002       Abed        Nadir   1236439775              No
# 2         1003     Walter       /White          NaN               N
# 3         1004     Dwight      Schrute   1235432345             Yes
# 4         1005        Jon         Snow   8766783469               Y
# 5         1006        Ron      Swanson   3047622467             Yes
# 6         1007       Jeff       Winger          NaN              No
# 7         1008   Sherlock       Holmes   8766783469               N
# 8         1009    Gandalf          NaN           Na             Yes
# 9         1010      Peter       Parker   1235455421             Yes
# 10        1011    Samwise       Gamgee          NaN             Yes
# 11        1012      Harry    ...Potter          NaN               Y
# 12        1013        Don       Draper   1235432345             Yes
# ...

# %%
# df1['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6]+'-'+ x[6:10])  # phone number columns is mixed data types ,,+ only works with string

# %%
df1['Phone_Number'].dtypes
# Out:
# dtype('O')

# %%
df1['Phone_Number']=df1['Phone_Number'].apply(lambda x: str(x))  # typecasted because concat or + only works with string

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421             Yes
# 1         1002       Abed        Nadir   1236439775              No
# 2         1003     Walter       /White          nan               N
# 3         1004     Dwight      Schrute   1235432345             Yes
# 4         1005        Jon         Snow   8766783469               Y
# 5         1006        Ron      Swanson   3047622467             Yes
# 6         1007       Jeff       Winger          nan              No
# 7         1008   Sherlock       Holmes   8766783469               N
# 8         1009    Gandalf          NaN           Na             Yes
# 9         1010      Peter       Parker   1235455421             Yes
# 10        1011    Samwise       Gamgee          nan             Yes
# 11        1012      Harry    ...Potter          nan               Y
# 12        1013        Don       Draper   1235432345             Yes
# ...

# %%
df1['Phone_Number']=df1['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6]+'-'+ x[6:10])

# %%
df1['Phone_Number']=df1['Phone_Number'].str.replace('nan--',"")

# %%
df1['Phone_Number']=df1['Phone_Number'].str.replace('Na--',"")

# %%
df1['Phone_Number'].dtypes
# Out:
# dtype('O')

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123-643-9775              No
# 2         1003     Walter       /White            --               N
# 3         1004     Dwight      Schrute  123-543-2345             Yes
# 4         1005        Jon         Snow  876-678-3469               Y
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger            --              No
# 7         1008   Sherlock       Holmes  876-678-3469               N
# 8         1009    Gandalf          NaN            --             Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee            --             Yes
# 11        1012      Harry    ...Potter            --               Y
# 12        1013        Don       Draper  123-543-2345             Yes
# ...

# %%
df1['Phone_Number']=df1['Phone_Number'].str.replace('--',"")

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123-643-9775              No
# 2         1003     Walter       /White                             N
# 3         1004     Dwight      Schrute  123-543-2345             Yes
# 4         1005        Jon         Snow  876-678-3469               Y
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger                            No
# 7         1008   Sherlock       Holmes  876-678-3469               N
# 8         1009    Gandalf          NaN                           Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee                           Yes
# 11        1012      Harry    ...Potter                             Y
# 12        1013        Don       Draper  123-543-2345             Yes
# ...

# %%
df1.iloc[1,3]
# Out:
# '123-643-9775'

# %%
type(df1.iloc[1,3])
# Out:
# str

# %%
b='14-'

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 int(b)
#
# ValueError: invalid literal for int() with base 10: '14-'

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421             Yes
# 1         1002       Abed        Nadir   1236439775              No
# 2         1003     Walter       /White                            N
# 3         1004     Dwight      Schrute   1235432345             Yes
# 4         1005        Jon         Snow   8766783469               Y
# 5         1006        Ron      Swanson   3047622467             Yes
# 6         1007       Jeff       Winger                           No
# 7         1008   Sherlock       Holmes   8766783469               N
# 8         1009    Gandalf          NaN                          Yes
# 9         1010      Peter       Parker   1235455421             Yes
# 10        1011    Samwise       Gamgee                          Yes
# 11        1012      Harry    ...Potter                            Y
# 12        1013        Don       Draper   1235432345             Yes
# ...

# %%
type(df1.iloc[0,3])
# Out:
# str

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins   1235455421             Yes
# 1         1002       Abed        Nadir   1236439775              No
# 2         1003     Walter       /White                            N
# 3         1004     Dwight      Schrute   1235432345             Yes
# 4         1005        Jon         Snow   8766783469               Y
# 5         1006        Ron      Swanson   3047622467             Yes
# 6         1007       Jeff       Winger                           No
# 7         1008   Sherlock       Holmes   8766783469               N
# 8         1009    Gandalf          NaN                          Yes
# 9         1010      Peter       Parker   1235455421             Yes
# 10        1011    Samwise       Gamgee                          Yes
# 11        1012      Harry    ...Potter                            Y
# 12        1013        Don       Draper   1235432345             Yes
# ...

# %%
#split

# %%
df1['Address']=df['Address']

# %%
df1[['Address']]
# Out:
#                                   Address
# 0                   123 Shire Lane, Shire
# 1                     93 West Main Street
# 2                      298 Drugs Driveway
# 3   980 Paper Avenue, Pennsylvania, 18503
# 4                        123 Dragons Road
# 5                        768 City Parkway
# 6                       1209 South Street
# 7                           98 Clue Drive
# 8                        123 Middle Earth
# 9              25th Main Street, New York
# 10                  612 Shire Lane, Shire
# 11                   2394 Hogwarts Avenue
# 12                       2039 Main Street
# 13                       343 City Parkway
# 14                          214 HR Avenue
# 15                   2395 Hogwarts Avenue
# 16         121 Paper Avenue, Pennsylvania
# 17                        3498 Super Lane
# 18                                    N/a
# 19            910 Tatooine Road, Tatooine

# %%
df1['Address'].str.split(',',2,expand=True)
# Out:
# C:\Users\DEVEN\AppData\Local\Temp\ipykernel_24052\488781744.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1['Address'].str.split(',',2,expand=True)
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# ...

# %%
df1[['street_Address','State','Zip']]=df1['Address'].str.split(',',2,expand=True)
# Out:
# C:\Users\DEVEN\AppData\Local\Temp\ipykernel_24052\3733199763.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1[['street_Address','State','Zip']]=df1['Address'].str.split(',',2,expand=True)

# %%
df1.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number Paying Customer  \
# 0        1001      Frodo   Baggins  123-545-5421             Yes
# 1        1002       Abed     Nadir  123-643-9775              No
# 2        1003     Walter    /White                             N
# 3        1004     Dwight   Schrute  123-543-2345             Yes
# 4        1005        Jon      Snow  876-678-3469               Y
#
#   Do_Not_Contact                                Address       street_Address  \
# 0             No                  123 Shire Lane, Shire       123 Shire Lane
# 1            Yes                    93 West Main Street  93 West Main Street
# 2            NaN                     298 Drugs Driveway   298 Drugs Driveway
# 3              Y  980 Paper Avenue, Pennsylvania, 18503     980 Paper Avenue
# 4             No                       123 Dragons Road     123 Dragons Road
#
#            State     Zip
# 0          Shire    None
# 1           None    None
# 2           None    None
# ...

# %%
df1.isna().sum()
# Out:
# CustomerID          0
# First_Name          0
# Last_Name           1
# Phone_Number        0
# Paying Customer     0
# Do_Not_Contact      4
# Address             0
# street_Address      0
# State              14
# Zip                19
# dtype: int64

# %%
df1['Zip'].isna().sum()
# Out:
# 19

# %%
df1.iloc[1,9]  # when we try to retreive none ,,nothing in output

# %%
df1.drop(columns='Address')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123-643-9775              No
# 2         1003     Walter       /White                             N
# 3         1004     Dwight      Schrute  123-543-2345             Yes
# 4         1005        Jon         Snow  876-678-3469               Y
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger                            No
# 7         1008   Sherlock       Holmes  876-678-3469               N
# 8         1009    Gandalf          NaN                           Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee                           Yes
# 11        1012      Harry    ...Potter                             Y
# 12        1013        Don       Draper  123-543-2345             Yes
# ...

# %%
df1.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number',
#        'Paying Customer', 'Do_Not_Contact', 'Address', 'street_Address',
#        'State', 'Zip'],
#       dtype='object')

# %%
df1['Paying Customer']=df1['Paying Customer'].str.replace('Yes','Y')
df1['Paying Customer']=df1['Paying Customer'].str.replace('No','N')

# %%
df1.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number Paying Customer  \
# 0        1001      Frodo   Baggins  123-545-5421               Y
# 1        1002       Abed     Nadir  123-643-9775               N
# 2        1003     Walter    /White                             N
# 3        1004     Dwight   Schrute  123-543-2345               Y
# 4        1005        Jon      Snow  876-678-3469               Y
#
#   Do_Not_Contact                                Address       street_Address  \
# 0             No                  123 Shire Lane, Shire       123 Shire Lane
# 1            Yes                    93 West Main Street  93 West Main Street
# 2            NaN                     298 Drugs Driveway   298 Drugs Driveway
# 3              Y  980 Paper Avenue, Pennsylvania, 18503     980 Paper Avenue
# 4             No                       123 Dragons Road     123 Dragons Road
#
#            State     Zip
# 0          Shire    None
# 1           None    None
# 2           None    None
# ...

# %%
df1['Do_Not_Contact']=df1['Do_Not_Contact'].str.replace('Yes','Y')
df1['Do_Not_Contact']=df1['Do_Not_Contact'].str.replace('No','N')

# %%
df1
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421               Y
# 1         1002       Abed        Nadir  123-643-9775               N
# 2         1003     Walter       /White                             N
# 3         1004     Dwight      Schrute  123-543-2345               Y
# 4         1005        Jon         Snow  876-678-3469               Y
# 5         1006        Ron      Swanson  304-762-2467               Y
# 6         1007       Jeff       Winger                             N
# 7         1008   Sherlock       Holmes  876-678-3469               N
# 8         1009    Gandalf          NaN                             Y
# 9         1010      Peter       Parker  123-545-5421               Y
# 10        1011    Samwise       Gamgee                             Y
# 11        1012      Harry    ...Potter                             Y
# 12        1013        Don       Draper  123-543-2345               Y
# ...

# %%
df1.iloc[18,6]
# Out:
# 'N/a'

# %%
type(df1.iloc[18,6])
# Out:
# str

# %%
df1=df1.replace('N/a',"")
df1=df1.replace('NaN',"")

# %%
df1['Last_Name']=df1['Last_Name'].str.strip('...,/,_')

# %%
df1  # still NaN
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123-643-9775               N
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf         NaN                             Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %%
df1.iloc[2,5]
# Out:
# nan

# %%
type(df1.iloc[2,5])
# Out:
# float

# %%
df1.fillna("",inplace=True)  # filled all nan which was not string with blank

# %%
df1
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123-643-9775               N
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %%
# remove y rows from do not call columns bcoz,,we only want available for call customers

# %%
for x in df1.index:
    if df1.loc[x, 'Do_Not_Contact'] == 'Y':
        df1.drop(x, inplace=True)

# %%
df1
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 2         1003     Walter       White                             N
# 4         1005        Jon        Snow  876-678-3469               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# ...

# %%
df1
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 1         1002       Abed       Nadir  123-643-9775               N
# 2         1003     Walter       White                             N
# 3         1004     Dwight     Schrute  123-543-2345               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 5         1006        Ron     Swanson  304-762-2467               Y
# 6         1007       Jeff      Winger                             N
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 8         1009    Gandalf                                         Y
# 9         1010      Peter      Parker  123-545-5421               Y
# 10        1011    Samwise      Gamgee                             Y
# 11        1012      Harry      Potter                             Y
# 12        1013        Don      Draper  123-543-2345               Y
# ...

# %%
#delete those rows win phone no. with null rows

# %%
for x in df1.index:
    if df1.loc[x,'Phone_Number']=='':
        df1.drop(x,inplace=True)
        
df1
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo     Baggins  123-545-5421               Y
# 4         1005        Jon        Snow  876-678-3469               Y
# 7         1008   Sherlock      Holmes  876-678-3469               N
# 9         1010      Peter      Parker  123-545-5421               Y
# 12        1013        Don      Draper  123-543-2345               Y
# 13        1014     Leslie       Knope  876-678-3469               Y
# 14        1015       Toby  Flenderson  304-762-2467               N
# 15        1016        Ron     Weasley  123-545-5421               N
# 16        1017   Michael        Scott  123-643-9775               Y
# 19        1020     Anakin   Skywalker  876-678-3469               Y
#
#    Do_Not_Contact                         Address        street_Address  \
# 0               N           123 Shire Lane, Shire        123 Shire Lane
# 4               N                123 Dragons Road      123 Dragons Road
# ...

# %%
# index is not in sequence

# %%
df1.reset_index(inplace=True)

# %%
df1
# Out:
#    index  CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0      0        1001      Frodo     Baggins  123-545-5421               Y
# 1      4        1005        Jon        Snow  876-678-3469               Y
# 2      7        1008   Sherlock      Holmes  876-678-3469               N
# 3      9        1010      Peter      Parker  123-545-5421               Y
# 4     12        1013        Don      Draper  123-543-2345               Y
# 5     13        1014     Leslie       Knope  876-678-3469               Y
# 6     14        1015       Toby  Flenderson  304-762-2467               N
# 7     15        1016        Ron     Weasley  123-545-5421               N
# 8     16        1017   Michael        Scott  123-643-9775               Y
# 9     19        1020     Anakin   Skywalker  876-678-3469               Y
#
#   Do_Not_Contact                         Address        street_Address  \
# 0              N           123 Shire Lane, Shire        123 Shire Lane
# ...

# %%
df1.drop(columns='index',inplace=True)

# %%
df1
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number Paying Customer  \
# 0        1001      Frodo     Baggins  123-545-5421               Y
# 1        1005        Jon        Snow  876-678-3469               Y
# 2        1008   Sherlock      Holmes  876-678-3469               N
# 3        1010      Peter      Parker  123-545-5421               Y
# 4        1013        Don      Draper  123-543-2345               Y
# 5        1014     Leslie       Knope  876-678-3469               Y
# 6        1015       Toby  Flenderson  304-762-2467               N
# 7        1016        Ron     Weasley  123-545-5421               N
# 8        1017   Michael        Scott  123-643-9775               Y
# 9        1020     Anakin   Skywalker  876-678-3469               Y
#
#   Do_Not_Contact                         Address        street_Address  \
# 0              N           123 Shire Lane, Shire        123 Shire Lane
# 1              N                123 Dragons Road      123 Dragons Road
# ...

# %%
## whole data is cleaned
